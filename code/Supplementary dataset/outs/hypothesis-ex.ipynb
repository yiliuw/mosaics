# %% [markdown]
# ### Complete HT table results
# We would like to include **p-values, overlap rate, intensity and confidence scores**.
# Allow easy adding cell types and qualified sections.

# %%
source("./scale.R")
test <- read.csv("/data/coro_data.csv")
test = test %>% rename(x = x_section, y = y_section)
options(warn=-1)
# Out:
# Loading required package: spatstat.data
#
# Loading required package: spatstat.univar
#
# spatstat.univar 3.1-1
#
# Loading required package: spatstat.geom
#
# spatstat.geom 3.3-4
#
# Loading required package: spatstat.random
#
# spatstat.random 3.3-2
#
# Loading required package: spatstat.explore
#
# Loading required package: nlme
#
# spatstat.explore 3.3-3
#
# Loading required package: spatstat.model
#
# Loading required package: rpart
#
# spatstat.model 3.3-3
#
# Loading required package: spatstat.linnet
#
# spatstat.linnet 3.2-3
#
#
# spatstat 3.3-0
# For an introduction to spatstat, type ‘beginner’
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:nlme’:
#
#     collapse
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
seeds <- sample(1:100,5,replace=FALSE)
seeds
# Out:
# [1] 62 94 29 81 28

# %%
library('foreach')
library('doParallel')
cores=detectCores()
cl <- makeCluster(cores[1]-1) #not to overload your computer
registerDoParallel(cl)
# Out:
# Loading required package: iterators
#
# Loading required package: parallel

# %% [markdown]
# ### HT table calculation

# %%
ecdf_fun <- function(x,perc) ecdf(x)(perc)
## Calculate column stats for each type
calc_pp_2d<-function(typ,pp,ps,section){
    nnp <- c()
    nni <- c()
    mnn <- c()
    res<- list()
    for (i in 1:length(pp)){     
        perc<- ecdf_fun(nndist(pp[[i]]), 0.01)
        int<- intensity(pp[[i]])
        mval<- mean(marks(pp[[i]]))
        nnp<-append(nnp,perc)
        nni<-append(nni,int)
        mnn <- append(mnn, mval)
        res[[as.character(section[i])]] = min(ps[,i])    
    }   
    pval <- signif(fisher(unname(unlist(res)))$p,2)
    res[['pval']] = pval
    res[['perc']] = round(mean(nnp)*100,2)
    res[['lam']] = round(mean(nni))
    res[['conf']] = round(mean(mnn),2)
    res[['rm']] = length(ps[,1])
    res[['Cluster']] = typ
    return(res)
}

# %% [markdown]
# ### Excitatory clusters
# We get the list of types and sections from the filtered table.

# %%
df<- read.csv("filter-exc.csv")
df1 <- replace(df, is.na(df), 0)
df1[df1<=0.5] <- NA
df1<-df1[rowSums(is.na(df1)) != ncol(df1)-1, ]
df1<-df1[!df1$cluster%in%(c('0109 L2/3 IT CTX Glut_2')), ]
row.names(df1) <- NULL

# %%
types = df1$cluster
types
# Out:
#  [1] "0042 L6 IT CTX Glut_2"   "0061 L5 IT CTX Glut_3"
#  [3] "0070 L4/5 IT CTX Glut_1" "0072 L4/5 IT CTX Glut_1"
#  [5] "0077 L4/5 IT CTX Glut_2" "0078 L4/5 IT CTX Glut_2"
#  [7] "0082 L4/5 IT CTX Glut_2" "0084 L4/5 IT CTX Glut_3"
#  [9] "0087 L4/5 IT CTX Glut_3" "0088 L4/5 IT CTX Glut_3"
# [11] "0091 L4/5 IT CTX Glut_4" "0094 L4/5 IT CTX Glut_4"
# [13] "0095 L4/5 IT CTX Glut_5" "0098 L4/5 IT CTX Glut_5"
# [15] "0104 L2/3 IT CTX Glut_1" "0105 L2/3 IT CTX Glut_1"
# [17] "0117 L2/3 IT CTX Glut_4" "0118 L2/3 IT CTX Glut_4"
# [19] "0350 L5 ET CTX Glut_1"   "0351 L5 ET CTX Glut_1"
# [21] "0364 L5 ET CTX Glut_2"   "0436 L6 CT CTX Glut_1"
# [23] "0444 L6 CT CTX Glut_2"   "0468 L5 NP CTX Glut_3"
# [25] "0473 L5 NP CTX Glut_4"

# %%
sections<- apply(df1[,-1], 1, function(i) colnames(df1[,-1])[ !is.na(i) ]) ## qualified colns
sections<- sapply(sections, function(x){as.numeric(gsub("X.", "", x))})

# %%
df = data.frame(matrix(vector(), 0, 9,
                dimnames=list(c(), c('Cluster','59','60','61',"pval", "perc", "lam",'conf','rm'))),
                stringsAsFactors=F)
df$Cluster <- as.character(df$Cluster)
df
# Out:
#      Cluster X59 X60 X61 pval perc lam conf rm

# %% [markdown]
# ### Table results
# We use the parallel version to implement the HT table for all excitatory clusters passing through the intensity filter.

# %%
set.seed(seeds[1])
res1 <- foreach(t = 0:length(types), .combine=function(x,y) bind_rows(as.data.frame(x),as.data.frame(y)),.packages=c('dplyr','spatstat','poolr')) %dopar% {
    if (t == 0){
        q <- df
    }
    else{
        pp<-create_pp(test, NULL,sections[[t]], types[t])
        rm<-min(as.numeric(quantile(do.call(c,lapply(pp, nndist)),0.5)),0.06) 
        ps<-get_pp_2d(pp, rm, TRUE)
        ## write into data frame
        q <- calc_pp_2d(types[t],pp,ps,sections[[t]])
        q
    }
}
res1
# Out:
#    Cluster                 X59   X60   X61   pval    perc lam  conf rm
# 1  0042 L6 IT CTX Glut_2   0.010 0.010    NA 1.0e-03 0.98  318 0.70 20
# 2  0061 L5 IT CTX Glut_3   0.025    NA    NA 2.5e-02 3.96  268 0.68 23
# 3  0070 L4/5 IT CTX Glut_1 0.005    NA    NA 5.0e-03 2.20  302 0.70 34
# 4  0072 L4/5 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 0.66  447 0.72 21
# 5  0077 L4/5 IT CTX Glut_2    NA 0.010 0.005 5.5e-04 1.39  427 0.70 23
# 6  0078 L4/5 IT CTX Glut_2 0.015 0.005 0.060 4.0e-04 1.42  279 0.73 24
# 7  0082 L4/5 IT CTX Glut_2 0.005 0.010 0.005 3.3e-05 0.00  423 0.71 29
# 8  0084 L4/5 IT CTX Glut_3 0.005 0.005 0.005 1.8e-05 0.80  335 0.71 29
# 9  0087 L4/5 IT CTX Glut_3    NA 0.005 0.005 2.9e-04 1.32  317 0.72 24
# 10 0088 L4/5 IT CTX Glut_3 0.280    NA    NA 2.8e-01 5.48  182 0.71 34
# 11 0091 L4/5 IT CTX Glut_4 0.005 0.005 0.005 1.8e-05 1.31  534 0.71 22
# 12 0094 L4/5 IT CTX Glut_4    NA    NA 0.010 1.0e-02 0.00  359 0.70 10
# 13 0095 L4/5 IT CTX Glut_5 0.005 0.005 0.005 1.8e-05 0.78  426 0.72 20
# 14 0098 L4/5 IT CTX Glut_5 0.005 0.005    NA 2.9e-04 1.45  369 0.70 20
# 15 0104 L2/3 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 3.83  875 0.72  6
# 16 0105 L2/3 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 1.29 1216 0.74 10
# 17 0117 L2/3 IT CTX Glut_4 0.010 0.005 0.005 3.3e-05 2.07  560 0.71 22
# 18 0118 L2/3 IT CTX Glut_4 0.010    NA    NA 1.0e-02 0.00  338 0.69 17
# 19 0350 L5 ET CTX Glut_1   0.030    NA    NA 3.0e-02 0.00  367 0.77 19
# 20 0351 L5 ET CTX Glut_1   0.005 0.010 0.010 6.0e-05 0.34  282 0.72 26
# 21 0364 L5 ET CTX Glut_2   0.050    NA    NA 5.0e-02 8.93  205 0.70 37
# 22 0436 L6 CT CTX Glut_1   0.005 0.005    NA 2.9e-04 1.38  737 0.74  9
# 23 0444 L6 CT CTX Glut_2   0.005    NA    NA 5.0e-03 0.00  329 0.71 26
# 24 0468 L5 NP CTX Glut_3      NA    NA 0.090 9.0e-02 0.00  132 0.75 36
# 25 0473 L5 NP CTX Glut_4      NA 0.040    NA 4.0e-02 4.44   73 0.70 51

# %%
write.csv(res1, "table-ex1.csv",row.names = FALSE)

# %%
set.seed(seeds[2])
res2 <- foreach(t = 0:length(types), .combine=function(x,y) bind_rows(as.data.frame(x),as.data.frame(y)),.packages=c('dplyr','spatstat','poolr')) %dopar% {
    if (t == 0){
        q <- df
    }
    else{
        pp<-create_pp(test, NULL,sections[[t]], types[t])
        rm<-min(as.numeric(quantile(do.call(c,lapply(pp, nndist)),0.5)),0.06) 
        ps<-get_pp_2d(pp, rm, TRUE)
        ## write into data frame
        q <- calc_pp_2d(types[t],pp,ps,sections[[t]])
        q
    }
}
res2
# Out:
#    Cluster                 X59   X60   X61   pval    perc lam  conf rm
# 1  0042 L6 IT CTX Glut_2   0.005 0.020    NA 1.0e-03 0.98  318 0.70 20
# 2  0061 L5 IT CTX Glut_3   0.040    NA    NA 4.0e-02 3.96  268 0.68 23
# 3  0070 L4/5 IT CTX Glut_1 0.005    NA    NA 5.0e-03 2.20  302 0.70 34
# 4  0072 L4/5 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 0.66  447 0.72 21
# 5  0077 L4/5 IT CTX Glut_2    NA 0.005 0.005 2.9e-04 1.39  427 0.70 23
# 6  0078 L4/5 IT CTX Glut_2 0.010 0.005 0.020 1.1e-04 1.42  279 0.73 24
# 7  0082 L4/5 IT CTX Glut_2 0.005 0.025 0.005 7.3e-05 0.00  423 0.71 29
# 8  0084 L4/5 IT CTX Glut_3 0.005 0.005 0.005 1.8e-05 0.80  335 0.71 29
# 9  0087 L4/5 IT CTX Glut_3    NA 0.005 0.005 2.9e-04 1.32  317 0.72 24
# 10 0088 L4/5 IT CTX Glut_3 0.280    NA    NA 2.8e-01 5.48  182 0.71 34
# 11 0091 L4/5 IT CTX Glut_4 0.005 0.005 0.005 1.8e-05 1.31  534 0.71 22
# 12 0094 L4/5 IT CTX Glut_4    NA    NA 0.015 1.5e-02 0.00  359 0.70 10
# 13 0095 L4/5 IT CTX Glut_5 0.005 0.005 0.005 1.8e-05 0.78  426 0.72 20
# 14 0098 L4/5 IT CTX Glut_5 0.005 0.005    NA 2.9e-04 1.45  369 0.70 20
# 15 0104 L2/3 IT CTX Glut_1 0.005 0.005 0.010 3.3e-05 3.83  875 0.72  6
# 16 0105 L2/3 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 1.29 1216 0.74 10
# 17 0117 L2/3 IT CTX Glut_4 0.005 0.005 0.005 1.8e-05 2.07  560 0.71 22
# 18 0118 L2/3 IT CTX Glut_4 0.010    NA    NA 1.0e-02 0.00  338 0.69 17
# 19 0350 L5 ET CTX Glut_1   0.015    NA    NA 1.5e-02 0.00  367 0.77 19
# 20 0351 L5 ET CTX Glut_1   0.005 0.005 0.010 3.3e-05 0.34  282 0.72 26
# 21 0364 L5 ET CTX Glut_2   0.045    NA    NA 4.5e-02 8.93  205 0.70 37
# 22 0436 L6 CT CTX Glut_1   0.005 0.005    NA 2.9e-04 1.38  737 0.74  9
# 23 0444 L6 CT CTX Glut_2   0.005    NA    NA 5.0e-03 0.00  329 0.71 26
# 24 0468 L5 NP CTX Glut_3      NA    NA 0.175 1.8e-01 0.00  132 0.75 36
# 25 0473 L5 NP CTX Glut_4      NA 0.070    NA 7.0e-02 4.44   73 0.70 51

# %%
write.csv(res2, "table-ex2.csv",row.names = FALSE)

# %%
set.seed(seeds[3])
res3 <- foreach(t = 0:length(types), .combine=function(x,y) bind_rows(as.data.frame(x),as.data.frame(y)),.packages=c('dplyr','spatstat','poolr')) %dopar% {
    if (t == 0){
        q <- df
    }
    else{
        pp<-create_pp(test, NULL,sections[[t]], types[t])
        rm<-min(as.numeric(quantile(do.call(c,lapply(pp, nndist)),0.5)),0.06) 
        ps<-get_pp_2d(pp, rm, TRUE)
        ## write into data frame
        q <- calc_pp_2d(types[t],pp,ps,sections[[t]])
        q
    }
}
res3
# Out:
#    Cluster                 X59   X60   X61   pval    perc lam  conf rm
# 1  0042 L6 IT CTX Glut_2   0.010 0.005    NA 5.5e-04 0.98  318 0.70 20
# 2  0061 L5 IT CTX Glut_3   0.030    NA    NA 3.0e-02 3.96  268 0.68 23
# 3  0070 L4/5 IT CTX Glut_1 0.005    NA    NA 5.0e-03 2.20  302 0.70 34
# 4  0072 L4/5 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 0.66  447 0.72 21
# 5  0077 L4/5 IT CTX Glut_2    NA 0.005 0.005 2.9e-04 1.39  427 0.70 23
# 6  0078 L4/5 IT CTX Glut_2 0.015 0.005 0.045 3.1e-04 1.42  279 0.73 24
# 7  0082 L4/5 IT CTX Glut_2 0.005 0.015 0.005 4.7e-05 0.00  423 0.71 29
# 8  0084 L4/5 IT CTX Glut_3 0.005 0.005 0.005 1.8e-05 0.80  335 0.71 29
# 9  0087 L4/5 IT CTX Glut_3    NA 0.005 0.005 2.9e-04 1.32  317 0.72 24
# 10 0088 L4/5 IT CTX Glut_3 0.325    NA    NA 3.2e-01 5.48  182 0.71 34
# 11 0091 L4/5 IT CTX Glut_4 0.005 0.005 0.005 1.8e-05 1.31  534 0.71 22
# 12 0094 L4/5 IT CTX Glut_4    NA    NA 0.010 1.0e-02 0.00  359 0.70 10
# 13 0095 L4/5 IT CTX Glut_5 0.005 0.005 0.005 1.8e-05 0.78  426 0.72 20
# 14 0098 L4/5 IT CTX Glut_5 0.005 0.005    NA 2.9e-04 1.45  369 0.70 20
# 15 0104 L2/3 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 3.83  875 0.72  6
# 16 0105 L2/3 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 1.29 1216 0.74 10
# 17 0117 L2/3 IT CTX Glut_4 0.010 0.005 0.005 3.3e-05 2.07  560 0.71 22
# 18 0118 L2/3 IT CTX Glut_4 0.015    NA    NA 1.5e-02 0.00  338 0.69 17
# 19 0350 L5 ET CTX Glut_1   0.025    NA    NA 2.5e-02 0.00  367 0.77 19
# 20 0351 L5 ET CTX Glut_1   0.005 0.005 0.005 1.8e-05 0.34  282 0.72 26
# 21 0364 L5 ET CTX Glut_2   0.075    NA    NA 7.5e-02 8.93  205 0.70 37
# 22 0436 L6 CT CTX Glut_1   0.005 0.005    NA 2.9e-04 1.38  737 0.74  9
# 23 0444 L6 CT CTX Glut_2   0.005    NA    NA 5.0e-03 0.00  329 0.71 26
# 24 0468 L5 NP CTX Glut_3      NA    NA 0.110 1.1e-01 0.00  132 0.75 36
# 25 0473 L5 NP CTX Glut_4      NA 0.215    NA 2.1e-01 4.44   73 0.70 51

# %%
write.csv(res3, "table-ex3.csv",row.names = FALSE)

# %%
set.seed(seeds[4])
res4 <- foreach(t = 0:length(types), .combine=function(x,y) bind_rows(as.data.frame(x),as.data.frame(y)),.packages=c('dplyr','spatstat','poolr')) %dopar% {
    if (t == 0){
        q <- df
    }
    else{
        pp<-create_pp(test, NULL,sections[[t]], types[t])
        rm<-min(as.numeric(quantile(do.call(c,lapply(pp, nndist)),0.5)),0.06) 
        ps<-get_pp_2d(pp, rm, TRUE)
        ## write into data frame
        q <- calc_pp_2d(types[t],pp,ps,sections[[t]])
        q
    }
}
res4
# Out:
#    Cluster                 X59   X60   X61   pval    perc lam  conf rm
# 1  0042 L6 IT CTX Glut_2   0.005 0.010    NA 5.5e-04 0.98  318 0.70 20
# 2  0061 L5 IT CTX Glut_3   0.030    NA    NA 3.0e-02 3.96  268 0.68 23
# 3  0070 L4/5 IT CTX Glut_1 0.005    NA    NA 5.0e-03 2.20  302 0.70 34
# 4  0072 L4/5 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 0.66  447 0.72 21
# 5  0077 L4/5 IT CTX Glut_2    NA 0.010 0.005 5.5e-04 1.39  427 0.70 23
# 6  0078 L4/5 IT CTX Glut_2 0.005 0.005 0.050 1.3e-04 1.42  279 0.73 24
# 7  0082 L4/5 IT CTX Glut_2 0.005 0.030 0.005 8.6e-05 0.00  423 0.71 29
# 8  0084 L4/5 IT CTX Glut_3 0.005 0.005 0.005 1.8e-05 0.80  335 0.71 29
# 9  0087 L4/5 IT CTX Glut_3    NA 0.005 0.005 2.9e-04 1.32  317 0.72 24
# 10 0088 L4/5 IT CTX Glut_3 0.250    NA    NA 2.5e-01 5.48  182 0.71 34
# 11 0091 L4/5 IT CTX Glut_4 0.005 0.005 0.005 1.8e-05 1.31  534 0.71 22
# 12 0094 L4/5 IT CTX Glut_4    NA    NA 0.010 1.0e-02 0.00  359 0.70 10
# 13 0095 L4/5 IT CTX Glut_5 0.005 0.005 0.005 1.8e-05 0.78  426 0.72 20
# 14 0098 L4/5 IT CTX Glut_5 0.005 0.010    NA 5.5e-04 1.45  369 0.70 20
# 15 0104 L2/3 IT CTX Glut_1 0.005 0.005 0.010 3.3e-05 3.83  875 0.72  6
# 16 0105 L2/3 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 1.29 1216 0.74 10
# 17 0117 L2/3 IT CTX Glut_4 0.005 0.005 0.005 1.8e-05 2.07  560 0.71 22
# 18 0118 L2/3 IT CTX Glut_4 0.010    NA    NA 1.0e-02 0.00  338 0.69 17
# 19 0350 L5 ET CTX Glut_1   0.040    NA    NA 4.0e-02 0.00  367 0.77 19
# 20 0351 L5 ET CTX Glut_1   0.005 0.010 0.030 1.6e-04 0.34  282 0.72 26
# 21 0364 L5 ET CTX Glut_2   0.090    NA    NA 9.0e-02 8.93  205 0.70 37
# 22 0436 L6 CT CTX Glut_1   0.005 0.005    NA 2.9e-04 1.38  737 0.74  9
# 23 0444 L6 CT CTX Glut_2   0.005    NA    NA 5.0e-03 0.00  329 0.71 26
# 24 0468 L5 NP CTX Glut_3      NA    NA 0.040 4.0e-02 0.00  132 0.75 36
# 25 0473 L5 NP CTX Glut_4      NA 0.305    NA 3.0e-01 4.44   73 0.70 51

# %%
write.csv(res4, "table-ex4.csv",row.names = FALSE)

# %%
set.seed(seeds[5])
res5 <- foreach(t = 0:length(types), .combine=function(x,y) bind_rows(as.data.frame(x),as.data.frame(y)),.packages=c('dplyr','spatstat','poolr')) %dopar% {
    if (t == 0){
        q <- df
    }
    else{
        pp<-create_pp(test, NULL,sections[[t]], types[t])
        rm<-min(as.numeric(quantile(do.call(c,lapply(pp, nndist)),0.5)),0.06) 
        ps<-get_pp_2d(pp, rm, TRUE)
        ## write into data frame
        q <- calc_pp_2d(types[t],pp,ps,sections[[t]])
        q
    }
}
res5
# Out:
#    Cluster                 X59   X60   X61   pval    perc lam  conf rm
# 1  0042 L6 IT CTX Glut_2   0.005 0.015    NA 7.9e-04 0.98  318 0.70 20
# 2  0061 L5 IT CTX Glut_3   0.050    NA    NA 5.0e-02 3.96  268 0.68 23
# 3  0070 L4/5 IT CTX Glut_1 0.005    NA    NA 5.0e-03 2.20  302 0.70 34
# 4  0072 L4/5 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 0.66  447 0.72 21
# 5  0077 L4/5 IT CTX Glut_2    NA 0.005 0.005 2.9e-04 1.39  427 0.70 23
# 6  0078 L4/5 IT CTX Glut_2 0.010 0.010 0.035 3.2e-04 1.42  279 0.73 24
# 7  0082 L4/5 IT CTX Glut_2 0.005 0.015 0.005 4.7e-05 0.00  423 0.71 29
# 8  0084 L4/5 IT CTX Glut_3 0.005 0.005 0.005 1.8e-05 0.80  335 0.71 29
# 9  0087 L4/5 IT CTX Glut_3    NA 0.005 0.005 2.9e-04 1.32  317 0.72 24
# 10 0088 L4/5 IT CTX Glut_3 0.240    NA    NA 2.4e-01 5.48  182 0.71 34
# 11 0091 L4/5 IT CTX Glut_4 0.005 0.005 0.005 1.8e-05 1.31  534 0.71 22
# 12 0094 L4/5 IT CTX Glut_4    NA    NA 0.010 1.0e-02 0.00  359 0.70 10
# 13 0095 L4/5 IT CTX Glut_5 0.005 0.005 0.005 1.8e-05 0.78  426 0.72 20
# 14 0098 L4/5 IT CTX Glut_5 0.005 0.010    NA 5.5e-04 1.45  369 0.70 20
# 15 0104 L2/3 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 3.83  875 0.72  6
# 16 0105 L2/3 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 1.29 1216 0.74 10
# 17 0117 L2/3 IT CTX Glut_4 0.005 0.005 0.005 1.8e-05 2.07  560 0.71 22
# 18 0118 L2/3 IT CTX Glut_4 0.005    NA    NA 5.0e-03 0.00  338 0.69 17
# 19 0350 L5 ET CTX Glut_1   0.010    NA    NA 1.0e-02 0.00  367 0.77 19
# 20 0351 L5 ET CTX Glut_1   0.005 0.020 0.010 1.1e-04 0.34  282 0.72 26
# 21 0364 L5 ET CTX Glut_2   0.045    NA    NA 4.5e-02 8.93  205 0.70 37
# 22 0436 L6 CT CTX Glut_1   0.005 0.005    NA 2.9e-04 1.38  737 0.74  9
# 23 0444 L6 CT CTX Glut_2   0.005    NA    NA 5.0e-03 0.00  329 0.71 26
# 24 0468 L5 NP CTX Glut_3      NA    NA 0.130 1.3e-01 0.00  132 0.75 36
# 25 0473 L5 NP CTX Glut_4      NA 0.305    NA 3.0e-01 4.44   73 0.70 51

# %%
write.csv(res5, "table-ex5.csv",row.names = FALSE)

# %%
res1$Cluster
# Out:
#  [1] "0042 L6 IT CTX Glut_2"   "0061 L5 IT CTX Glut_3"
#  [3] "0070 L4/5 IT CTX Glut_1" "0072 L4/5 IT CTX Glut_1"
#  [5] "0077 L4/5 IT CTX Glut_2" "0078 L4/5 IT CTX Glut_2"
#  [7] "0082 L4/5 IT CTX Glut_2" "0084 L4/5 IT CTX Glut_3"
#  [9] "0087 L4/5 IT CTX Glut_3" "0088 L4/5 IT CTX Glut_3"
# [11] "0091 L4/5 IT CTX Glut_4" "0094 L4/5 IT CTX Glut_4"
# [13] "0095 L4/5 IT CTX Glut_5" "0098 L4/5 IT CTX Glut_5"
# [15] "0104 L2/3 IT CTX Glut_1" "0105 L2/3 IT CTX Glut_1"
# [17] "0117 L2/3 IT CTX Glut_4" "0118 L2/3 IT CTX Glut_4"
# [19] "0350 L5 ET CTX Glut_1"   "0351 L5 ET CTX Glut_1"
# [21] "0364 L5 ET CTX Glut_2"   "0436 L6 CT CTX Glut_1"
# [23] "0444 L6 CT CTX Glut_2"   "0468 L5 NP CTX Glut_3"
# [25] "0473 L5 NP CTX Glut_4"

# %%
pv = c()
for(i in 1:nrow(res)) {
    row <- na.omit(unlist(unname(res[i,2:4])))
    pval <- signif(fisher(row)$p,2)
    pv<-append(pv,pval)
}
pv
# Out:
#  [1] 8.7e-04 3.5e-02 5.0e-03 1.8e-05 3.9e-04 2.7e-04 5.8e-05 1.8e-05 2.9e-04
# [10] 2.8e-01 1.8e-05 1.1e-02 1.8e-05 3.9e-04 2.4e-05 1.8e-05 2.4e-05 1.0e-02
# [19] 2.4e-02 7.6e-05 6.1e-02 2.9e-04 5.0e-03 1.1e-01 1.9e-01

# %%
res<-Reduce("+", list(res1[,2:6],res2[,2:6],res3[,2:6],res4[,2:6],res5[,2:6])) / 5
res<-data.frame(Cluster=res1$Cluster, res)
res$pval<-pv
res$perc<-res1$perc
res$lam<-res1$lam
res$conf<-res1$conf
res$rm<-res1$rm
res
# Out:
#    Cluster                 X59   X60   X61   pval    perc lam  conf rm
# 1  0042 L6 IT CTX Glut_2   0.007 0.012    NA 8.7e-04 0.98  318 0.70 20
# 2  0061 L5 IT CTX Glut_3   0.035    NA    NA 3.5e-02 3.96  268 0.68 23
# 3  0070 L4/5 IT CTX Glut_1 0.005    NA    NA 5.0e-03 2.20  302 0.70 34
# 4  0072 L4/5 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 0.66  447 0.72 21
# 5  0077 L4/5 IT CTX Glut_2    NA 0.007 0.005 3.9e-04 1.39  427 0.70 23
# 6  0078 L4/5 IT CTX Glut_2 0.011 0.006 0.042 2.7e-04 1.42  279 0.73 24
# 7  0082 L4/5 IT CTX Glut_2 0.005 0.019 0.005 5.8e-05 0.00  423 0.71 29
# 8  0084 L4/5 IT CTX Glut_3 0.005 0.005 0.005 1.8e-05 0.80  335 0.71 29
# 9  0087 L4/5 IT CTX Glut_3    NA 0.005 0.005 2.9e-04 1.32  317 0.72 24
# 10 0088 L4/5 IT CTX Glut_3 0.275    NA    NA 2.8e-01 5.48  182 0.71 34
# 11 0091 L4/5 IT CTX Glut_4 0.005 0.005 0.005 1.8e-05 1.31  534 0.71 22
# 12 0094 L4/5 IT CTX Glut_4    NA    NA 0.011 1.1e-02 0.00  359 0.70 10
# 13 0095 L4/5 IT CTX Glut_5 0.005 0.005 0.005 1.8e-05 0.78  426 0.72 20
# 14 0098 L4/5 IT CTX Glut_5 0.005 0.007    NA 3.9e-04 1.45  369 0.70 20
# 15 0104 L2/3 IT CTX Glut_1 0.005 0.005 0.007 2.4e-05 3.83  875 0.72  6
# 16 0105 L2/3 IT CTX Glut_1 0.005 0.005 0.005 1.8e-05 1.29 1216 0.74 10
# 17 0117 L2/3 IT CTX Glut_4 0.007 0.005 0.005 2.4e-05 2.07  560 0.71 22
# 18 0118 L2/3 IT CTX Glut_4 0.010    NA    NA 1.0e-02 0.00  338 0.69 17
# 19 0350 L5 ET CTX Glut_1   0.024    NA    NA 2.4e-02 0.00  367 0.77 19
# 20 0351 L5 ET CTX Glut_1   0.005 0.010 0.013 7.6e-05 0.34  282 0.72 26
# 21 0364 L5 ET CTX Glut_2   0.061    NA    NA 6.1e-02 8.93  205 0.70 37
# 22 0436 L6 CT CTX Glut_1   0.005 0.005    NA 2.9e-04 1.38  737 0.74  9
# 23 0444 L6 CT CTX Glut_2   0.005    NA    NA 5.0e-03 0.00  329 0.71 26
# 24 0468 L5 NP CTX Glut_3      NA    NA 0.109 1.1e-01 0.00  132 0.75 36
# 25 0473 L5 NP CTX Glut_4      NA 0.187    NA 1.9e-01 4.44   73 0.70 51

# %%
write.csv(res, "table-ex.csv",row.names = FALSE)
